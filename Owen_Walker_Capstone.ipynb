# %%
import pandas as pd
import json

# %% [markdown]
# ## Importing Most Followed Streamer Data Set

# %%
mfstream = pd.read_csv('./data/Most_Followers_three_days.csv')

# %%
mfstream.head(2)
# Out:
#                                           Unnamed: 0  Unnamed: 1 Channel  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...           1   Ninja
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...           2    Tfue
#
#    Watch time  Stream time  Peak viewers  Average viewers  Followers  \
# 0     8214510          720         15570            10949   16469658
# 1    24031665         1680         53438            13240    9742302
#
#    Followers gained  Views gained  Partnered  Mature Language Unnamed: 13
# 0             11911        436545       True   False  English       Ninja
# 1             22439        616332       True   False  English        Tfue

# %%
mfstream = mfstream.drop(columns = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 13'])

# %%
mfstream.head()
# Out:
#     Channel  Watch time  Stream time  Peak viewers  Average viewers  \
# 0     Ninja     8214510          720         15570            10949
# 1      Tfue    24031665         1680         53438            13240
# 2    shroud    27108015         1230         30920            17825
# 3      Myth     1612470          390          5603             4134
# 4  pokimane    10662570          600         31844            19896
#
#    Followers  Followers gained  Views gained  Partnered  Mature Language
# 0   16469658             11911        436545       True   False  English
# 1    9742302             22439        616332       True   False  English
# 2    8609552             11195        626494       True   False  English
# 3    7076540               872         66656       True   False  English
# 4    6715772             30149        559517       True   False  English

# %% [markdown]
# ## Importing Most Watched Streamer Data set

# %%
mwstream = pd.read_csv('./data/most_watched_streamers.csv')

# %%
mwstream.head()
# Out:
#                                           Unnamed: 0  Unnamed: 1  \
# 0  https://static-cdn.jtvnw.net/jtv_user_pictures...           1
# 1  https://static-cdn.jtvnw.net/jtv_user_pictures...           2
# 2  https://static-cdn.jtvnw.net/jtv_user_pictures...           3
# 3  https://static-cdn.jtvnw.net/jtv_user_pictures...           4
# 4  https://static-cdn.jtvnw.net/jtv_user_pictures...           5
#
#          Channel  Watch time  Stream time  Peak viewers  Average viewers  \
# 0           ibai   132391320         1050        261328           117179
# 1          xQcOW   106420740         1785         75989            59552
# 2      Asmongold    97432065         1455        126200            68182
# 3         Gaules    88518180         4290         92951            20642
# 4  limit_maximum    88386420         2415         75970            36852
#
#    Followers  Followers gained  Views gained  Partnered  Mature    Language  \
# ...

# %%
mwstream = mwstream.drop(columns = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 13'])

# %%
mwstream.head()
# Out:
#          Channel  Watch time  Stream time  Peak viewers  Average viewers  \
# 0           ibai   132391320         1050        261328           117179
# 1          xQcOW   106420740         1785         75989            59552
# 2      Asmongold    97432065         1455        126200            68182
# 3         Gaules    88518180         4290         92951            20642
# 4  limit_maximum    88386420         2415         75970            36852
#
#    Followers  Followers gained  Views gained  Partnered  Mature    Language
# 0    4177020             78874       4437941       True   False     Spanish
# 1    4389067             25487       1566960       True   False     English
# 2    1848011             21662       1945478       True   False     English
# 3    2248735             11206       1248532       True    True  Portuguese
# 4     201005             19677       1431397       True   False     English

# %% [markdown]
# ## Importing Most Watched Games on Twitch

# %%
mwgames = pd.read_csv('./data/most_watched_games_twitch.csv')

# %%
mwgames.head()
# Out:
#               Unnamed: 0  Unnamed: 1                   Game  Watch time  \
# 0          Just Chatting           1          Just Chatting  1446634500
# 1      World of Warcraft           2      World of Warcraft   786294300
# 2  Call of Duty: Warzone           3  Call of Duty: Warzone   559050900
# 3      League of Legends           4      League of Legends   543214860
# 4               Fortnite           5               Fortnite   516702240
#
#    Stream time  Peak viewers  Peak channels  Streamers  Average viewers  \
# 0     17181780        721587           5437      93519           334869
# 1     14728920        363789           7803      33932           182012
# 2     16582320        343398           7996      51623           129409
# 3     18853320        318449           6128      61174           125744
# 4     32494680        343767          12185     125201           119607
#
#    Average channels  Average viewer ratio  Followers gained  Views gained  \
# ...

# %%
mwgames = mwgames.drop(columns = ['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 15'])

# %%
mwgames.head()
# Out:
#                     Game  Watch time  Stream time  Peak viewers  \
# 0          Just Chatting  1446634500     17181780        721587
# 1      World of Warcraft   786294300     14728920        363789
# 2  Call of Duty: Warzone   559050900     16582320        343398
# 3      League of Legends   543214860     18853320        318449
# 4               Fortnite   516702240     32494680        343767
#
#    Peak channels  Streamers  Average viewers  Average channels  \
# 0           5437      93519           334869              3977
# 1           7803      33932           182012              3409
# 2           7996      51623           129409              3838
# 3           6128      61174           125744              4364
# 4          12185     125201           119607              7521
#
#    Average viewer ratio  Followers gained  Views gained       FPR         VPR
# 0                 84.20           1072995      33590391  3.746975  117.300039
# ...

# %% [markdown]
# ## YT data

# %%
with open('./data/ytdataset.json', "rb") as f: 
    ytd = json.load(f)

# %%
ytd = pd.DataFrame(ytd)

# %%
ytd.shape
# Out:
# (575610, 26)

# %%
ytd.head()
# Out:
#   totalviews/channelelapsedtime                 channelId videoCategoryId  \
# 0           0.16519925596076884  UCdzU3DSGzyWzN2118yd9X9g              22
# 1            1.1338200815767217  UC0UnhAG47DRyVZGVcbhAXhQ              10
# 2            0.6681201550387597  UCXjtAvK5P3wXBGh0vbGylzg              27
# 3             25.65350494473531  UCeKHMeUlcLNPLCLUfZUQI2w              26
# 4            52.773777521761396  UCNWPDyaWf2eAHnofFLSnEMg              20
#
#   channelViewCount      likes/subscriber   views/subscribers videoCount  \
# 0            14654    0.5555555555555556   95.11111111111111         30
# 1           105909    0.2391304347826087   59.32608695652174         51
# 2            48265  0.023668639053254437  10.289940828402367         72
# 3          2116722  0.007301256178858102  0.8841775883179901        172
# 4          1649075  0.004545454545454545  10.004545454545454       2777
#
#   subscriberCount      videoId          dislikes/views  ...  \
# ...

# %%
ytnames = pd.read_csv('./data/YouTube_Names.csv')

# %%
ytnames.head()
# Out:
#                          Name                        ID
# 0                      Zee TV  UCppHT7SZKKvar4Oc9J4oljQ
# 1                    T-Series  UCq-Fj5jknLsUf-MWSy4_brA
# 2  Cocomelon - Nursery Rhymes  UCbCmjCuTUZos6Inko4u57UQ
# 3                   SET India  UCpEhnqL0y41EpW2TvWAHD7Q
# 4                         WWE  UCJ5v_MCY6GNUBTO8-D3XoAg

# %%
ytnames.shape
# Out:
# (4998, 2)

# %%
ytnames.columns
# Out:
# Index(['Name', ' ID'], dtype='object')

# %%
ytset = ytd.merge(ytnames, how = 'left', left_on = 'channelId', right_on = ' ID')

# %%
ytset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 575868 entries, 0 to 575867
# Data columns (total 28 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   totalviews/channelelapsedtime  575868 non-null  object
#  1   channelId                      575868 non-null  object
#  2   videoCategoryId                575868 non-null  object
#  3   channelViewCount               575868 non-null  object
#  4   likes/subscriber               575868 non-null  object
#  5   views/subscribers              575868 non-null  object
#  6   videoCount                     575868 non-null  object
#  7   subscriberCount                575868 non-null  object
#  8   videoId                        575868 non-null  object
#  9   dislikes/views                 575868 non-null  object
#  10  channelelapsedtime             575868 non-null  object
#  11  comments/subscriber            575868 non-null  object
# ...
